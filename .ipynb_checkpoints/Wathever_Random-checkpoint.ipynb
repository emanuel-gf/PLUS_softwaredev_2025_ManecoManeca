# %%
import numpy as np

# %%
import plotly.express as px
import numpy as np
img_rgb = np.array([[[255, 0, 0], [0, 255, 0], [0, 0, 255]],
                    [[0, 255, 0], [0, 0, 255], [255, 0, 0]]
                   ], dtype=np.uint8)
fig = px.imshow(img_rgb)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import plotly.express as px
#       2 import numpy as np
#       3 img_rgb = np.array([[[255, 0, 0], [0, 255, 0], [0, 0, 255]],
#       4                     [[0, 255, 0], [0, 0, 255], [255, 0, 0]]
#       5                    ], dtype=np.uint8)
#
# ModuleNotFoundError: No module named 'plotly'

# %%
pip install plotly

# %%
import hello_world
# Out:
# showing the sys.path
# ['C:\\Users\\Emanuel\\Miniconda3\\python312.zip', 'C:\\Users\\Emanuel\\Miniconda3\\DLLs', 'C:\\Users\\Emanuel\\Miniconda3\\Lib', 'C:\\Users\\Emanuel\\Miniconda3', '', 'C:\\Users\\Emanuel\\Miniconda3\\Lib\\site-packages', 'C:\\Users\\Emanuel\\Miniconda3\\Lib\\site-packages\\win32', 'C:\\Users\\Emanuel\\Miniconda3\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\Emanuel\\Miniconda3\\Lib\\site-packages\\Pythonwin']
# hello world, hello monday

# %%
from hello_world import say_hello

# %%
say_hello()
# Out:
# hello world, hello monday
